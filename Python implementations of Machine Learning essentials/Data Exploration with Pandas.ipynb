# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# #### Creating a DataFrame to store the data

# %%
df = pd.read_csv('train.csv') # 'df' is a variable that stores the data from the csv file

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### To display the first five columns of the data

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### To get the summary of all the features in the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# #### To get a statistical summary of the features

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Indexing

# %% [markdown]
# #### To get the data of a particular row

# %%
df.iloc[5] # Returns all the data of passenger number 6
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %% [markdown]
# #### To get the values of a particular column

# %%
df.loc[0:4, 'Ticket']
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
df['Ticket'].head()
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
df[['Embarked','Ticket']].head()
# Out:
#   Embarked            Ticket
# 0        S         A/5 21171
# 1        C          PC 17599
# 2        S  STON/O2. 3101282
# 3        S            113803
# 4        S            373450

# %% [markdown]
# ## Selections

# %%
df[df['Age'] > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df['Age']>70
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df.query("Age > 70")
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df[(df['Age'] == 11) & (df['SibSp'] == 5)]
# Out:
#     PassengerId  Survived  Pclass                                Name   Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick  male
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59  11.0      5      2  CA 2144  46.9   NaN        S

# %%
df[(df.Age == 11) | (df.SibSp == 5)]
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 59            60         0       3   Goodwin, Master. William Frederick
# 71            72         0       3           Goodwin, Miss. Lillian Amy
# 386          387         0       3      Goodwin, Master. Sidney Leonard
# 480          481         0       3       Goodwin, Master. Harold Victor
# 542          543         0       3    Andersson, Miss. Sigrid Elisabeth
# 683          684         0       3          Goodwin, Mr. Charles Edward
# 731          732         0       3             Hassan, Mr. Houssein G N
# 802          803         1       1  Carter, Master. William Thornton II
#
#         Sex   Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# 59     male  11.0      5      2  CA 2144   46.9000      NaN        S
# 71   female  16.0      5      2  CA 2144   46.9000      NaN        S
# 386    male   1.0      5      2  CA 2144   46.9000      NaN        S
# ...

# %%
df.query('(Age == 11) | (SibSp == 5)')
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 59            60         0       3   Goodwin, Master. William Frederick
# 71            72         0       3           Goodwin, Miss. Lillian Amy
# 386          387         0       3      Goodwin, Master. Sidney Leonard
# 480          481         0       3       Goodwin, Master. Harold Victor
# 542          543         0       3    Andersson, Miss. Sigrid Elisabeth
# 683          684         0       3          Goodwin, Mr. Charles Edward
# 731          732         0       3             Hassan, Mr. Houssein G N
# 802          803         1       1  Carter, Master. William Thornton II
#
#         Sex   Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# 59     male  11.0      5      2  CA 2144   46.9000      NaN        S
# 71   female  16.0      5      2  CA 2144   46.9000      NaN        S
# 386    male   1.0      5      2  CA 2144   46.9000      NaN        S
# ...

# %% [markdown]
# ## Unique Values - Return unique values in a column

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# ## Sorting

# %%
df.sort_values('Age', ascending = False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %% [markdown]
# ## Group by query

# %%
df.groupby(['Pclass','Survived'])['PassengerId'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: PassengerId, dtype: int64

# %% [markdown]
# ## Pivot Table

# %%
df.pivot_table(index = 'Pclass',
              columns='Survived',
              values='PassengerId',
              aggfunc='count')
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %% [markdown]
# ## Finding Correlations between features

# %%
correlated_with_survived = df.corr()['Survived'].sort_values()

# %%
correlated_with_survived
# Out:
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# PassengerId   -0.005007
# Parch          0.081629
# Fare           0.257307
# Survived       1.000000
# Name: Survived, dtype: float64
