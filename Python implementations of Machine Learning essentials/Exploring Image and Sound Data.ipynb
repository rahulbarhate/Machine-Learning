# %% [markdown]
# ## Images

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Exception ignored in: <bound method Wave_write.__del__ of <wave.Wave_write object at 0x00000246645CF080>>
# Traceback (most recent call last):
#   File "c:\users\asus\appdata\local\programs\python\python35\lib\wave.py", line 316, in __del__
#     self.close()
#   File "c:\users\asus\appdata\local\programs\python\python35\lib\wave.py", line 434, in close
#     self._ensure_header_written(0)
#   File "c:\users\asus\appdata\local\programs\python\python35\lib\wave.py", line 457, in _ensure_header_written
#     self._write_header(datasize)
#   File "c:\users\asus\appdata\local\programs\python\python35\lib\wave.py", line 474, in _write_header
#     self._sampwidth * 8, b'data'))
# struct.error: ushort format requires 0 <= number <= 0xffff

# %%
img = Image.open('iss.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=272x185 at 0x24655B3D2B0>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# #### Converting the image into numpy array

# %%
imgarray = np.asarray(img)

# %%
type(imgarray)
# Out:
# numpy.ndarray

# %%
imgarray.shape
# Out:
# (185, 272, 3)

# %%
imgarray.ravel().shape #ravel() finction returns contiguous flattened array(1D array with all the input-array elements)
# Out:
# (150960,)

# %%
185 * 272 * 3
# Out:
# 150960

# %% [markdown]
# ## Sound

# %%
from scipy.io import wavfile

# %%
rate, snd = wavfile.read(filename = 'sms.wav')

# %%
from IPython.display import Audio

# %%
Audio(data = snd, rate = rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(snd)
# Out:
# 110250

# %%
snd
# Out:
# array([70, 14, 27, ..., 58, 68, 59], dtype=int16)

# %%
plt.plot(snd)

# %% [markdown]
# ## Plotting a Spectogram

# %%
_ = plt.specgram(snd, NFFT = 1024, Fs = 44100)
plt.ylabel('Frequency (Hz)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')
